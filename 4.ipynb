# %%
pre_cost = 2.0E+7
pre_cost
pre_cost = 2000*1.0E+4
pre_cost
fix_cost = 1000*1.0E+4
fix_cost
cost = pre_cost + fix_cost
cost
import math

def calc_earnings(pre_cost):
  earnings = 2.87E+07 * math.log(pre_cost) - 4.44E+08
  return int(earnings)
earnings = calc_earnings(pre_cost)
earnings
def calc_profit(earnings, cost):
 profit = earnings - cost
 return int(profit)
pre_cost = 2.0E+7
pre_cost
pre_cost = 2000*1.0E+4
pre_cost
fix_cost = 1000*1.0E+4
fix_cost
cost = pre_cost + fix_cost
cost
import math

def calc_earnings(pre_cost):
  earnings = 2.87E+07 * math.log(pre_cost) - 4.44E+08
  return int(earnings)
earnings = calc_earnings(pre_cost)
earnings
def calc_profit(earnings, cost):
 profit = earnings - cost
 return int(profit)
pre_cost = 2.0E+7
pre_cost
pre_cost = 2000*1.0E+4
pre_cost
fix_cost = 1000*1.0E+4
fix_cost
cost = pre_cost + fix_cost
cost
import math

def calc_earnings(pre_cost):
  earnings = 2.87E+07 * math.log(pre_cost) - 4.44E+08
  return int(earnings)
earnings = calc_earnings(pre_cost)
earnings
def calc_profit(earnings, cost):
 profit = earnings - cost
 return int(profit)
pre_cost = 2.0E+7
pre_cost
pre_cost = 2000*1.0E+4
pre_cost
fix_cost = 1000*1.0E+4
fix_cost
cost = pre_cost + fix_cost
cost
import math

def calc_earnings(pre_cost):
  earnings = 2.87E+07 * math.log(pre_cost) - 4.44E+08
  return int(earnings)
earnings = calc_earnings(pre_cost)
earnings
def calc_profit(earnings, cost):
 profit = earnings - cost
 return int(profit)
pre_cost = 2.0E+7
pre_cost
pre_cost = 2000*1.0E+4
pre_cost
fix_cost = 1000*1.0E+4
fix_cost
cost = pre_cost + fix_cost
cost
import math

def calc_earnings(pre_cost):
  earnings = 2.87E+07 * math.log(pre_cost) - 4.44E+08
  return int(earnings)
earnings = calc_earnings(pre_cost)
earnings
def calc_profit(earnings, cost):
 profit = earnings - cost
 return int(profit)
pre_cost = 2.0E+7
pre_cost
pre_cost = 2000*1.0E+4
pre_cost
fix_cost = 1000*1.0E+4
fix_cost
cost = pre_cost + fix_cost
cost
import math

def calc_earnings(pre_cost):
  earnings = 2.87E+07 * math.log(pre_cost) - 4.44E+08
  return int(earnings)
earnings = calc_earnings(pre_cost)
earnings
def calc_profit(earnings, cost):
 profit = earnings - cost
 return int(profit)
pre_cost = 2.0E+7
pre_cost
pre_cost = 2000*1.0E+4
pre_cost
fix_cost = 1000*1.0E+4
fix_cost
cost = pre_cost + fix_cost
cost
import math

def calc_earnings(pre_cost):
  earnings = 2.87E+07 * math.log(pre_cost) - 4.44E+08
  return int(earnings)
earnings = calc_earnings(pre_cost)
earnings
def calc_profit(earnings, cost):
 profit = earnings - cost
 return int(profit)
profit = calc_profit(earnings, cost)
profit
profit_ratio = int(profit / cost * 100)
profit_ratio
list(range(1000, 9001, 1))[:5]

data_ad_cost = list(range(1000, 9001, 1))
a = [1,2,3,4,5]
b = [_a*10 for _a in a]
b
data_earnings = [calc_earnings(pre_cost*1.0E+04) for pre_cost in data_ad_cost]
data_earnings[:5]
a = [1, 2, 3]
b = [4, 5, 6]
c = []
for _a, _b in zip(a, b):
 c.append(_a * _b)
c
data_profit = [calc_profit(earnings, pre_cost*1.0E+04 + fix_cost) for earnings, pre_cost in
zip(data_earnings, data_ad_cost)]
data_profit[:5]
data_profit[1000]
# !pip3 install matplotlib
import matplotlib.pyplot as plt
plt.plot(data_ad_cost, data_earnings, color='blue')
plt.plot(data_ad_cost, data_profit, color='green')
plt.show()
max_profit = max(data_profit)
max_profit
data_profit.index(max_profit)
best_ad_cost = data_ad_cost[data_profit.index(max_profit)]
best_ad_cost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/ato/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: numpy>=1.23 in /Users/ato/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: cycler>=0.10 in /Users/ato/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/ato/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ato/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /Users/ato/Library/Python/3.9/lib/python/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ato/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ato/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ato/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Users/ato/Library/Python/3.9/lib/python/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ato/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ato/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# 2870
